% %% [markdown]
% # Model balanced reduction in matlab

% %%
s = tf('s')
% Out:
% s =
%
%   s
%
% Continuous-time transfer function.

% %%
H = 1 / (s^3 + 6 * s^2 + 11 * s + 6)
% Out:
% H =
%
%             1
%   ----------------------
%   s^3 + 6 s^2 + 11 s + 6
%
% Continuous-time transfer function.

% %%
Hr = balred(H,2)
% Out:
% Hr =
%
%   0.004223 s^2 - 0.04253 s + 0.2368
%   ---------------------------------
%         s^2 + 2.343 s + 1.421
%
% Continuous-time transfer function.

% %%
step(H)
hold on
step(Hr)
